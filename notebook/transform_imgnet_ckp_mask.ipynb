# %%
import tensorflow as tf
import numpy as np
import os
from tensorflow.python.tools import inspect_checkpoint as chkp
from tensorflow.python import pywrap_tensorflow

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
imgnet_ckp = "/work/wangyu/imagenet/resnet_imagenet_v2_fp32_20181001/model.ckpt-225207"
save_path = '/work/wangyu/imagenet/resnet_v2_imagenet_transformed_mask/resnet50_v2_mask.ckpt'

# %%
def get_filters(reader, tensor_key):
    filters = np.array(reader.get_tensor(tensor_key))
    filters_shape = np.shape(filters)
    print('Read filter {0}, {1}'.format(tensor_key, filters_shape))
    return filters

def trans_filters(kernels):
    # from 1x1xinxout to 3x3xinxout
    kernel_shape = np.shape(kernels)
    num_filters = kernel_shape[3]
    filters = []
    for filter_i in range(num_filters):
        ker = kernels[:,:,:,filter_i] # [1, 1, c]
        expand_ker = np.tile(ker, [3,3,1]) # [3,3,c]
        filters.append(expand_ker)
    pack_kernel = np.stack(filters, axis=-1) # [3,3,c,num_filters]
    return pack_kernel

# %%
def trans_init_filters(kernels):
    # from [7x7x3, 64] to [7x7x4, 64]
    shape_ker = np.shape(kernels)
    Cout = shape_ker[3]
    final_filter = np.array([0], np.float32)
    # loop for adding input channel filters
    for i in range(Cout):
        filt = kernels[:,:,:,i] # [7,7,3]
        add_filter = np.clip(np.random.normal(loc=0.0, scale=0.01, size=[7,7]), -0.01, 0.01) # [7,7]
        add_filter = add_filter[..., np.newaxis] # [7,7,1]
        
        new_filter = np.concatenate((filt, add_filter), -1) # [7,7,4]
        new_filter = new_filter[..., np.newaxis] # [7,7,4,1]

        if i == 0:
            final_filter = new_filter # [7,7,4,1]
        else:
            final_filter = np.concatenate((final_filter,new_filter),-1) # [7,7,4,Cout]
    # check size
    new_shape = np.shape(final_filter)
    if new_shape[0] != new_shape[1] or new_shape[0] != 7:
        raise ValueError('kernel size {} != 7'.format(new_shape[0]))
    if new_shape[2] != 4:
        raise ValueError('In channel {} != 4'.format(new_shape[2]))
    if new_shape[3] != 64:
        raise ValueError('Out channel {} != 64'.format(new_shape[3]))
    
    return final_filter.astype(np.float32)

# %%
reader = pywrap_tensorflow.NewCheckpointReader(imgnet_ckp)

################## Initial conv ##################
tmp_f = get_filters(reader, 'resnet_model/conv2d/kernel')
templar_f = trans_init_filters(tmp_f)
_ = tf.Variable(templar_f, name='temp_begin/kernel')
search_f = trans_init_filters(tmp_f)
_ = tf.Variable(search_f, name='search_begin/kernel')

################## C2 ###########################
# 1st block, shortcut conv
tmp_f = get_filters(reader, 'resnet_model/conv2d_1/kernel')
_ = tf.Variable(tmp_f,  name='backbone/C2/block1/shortcut/kernel')
# 1st block, conv1
tmp_f = get_filters(reader, 'resnet_model/conv2d_2/kernel')
_ = tf.Variable(tmp_f,  name='backbone/C2/block1/conv1/kernel')
tmp_f = get_filters(reader, 'resnet_model/batch_normalization/beta')
_ = tf.Variable(tmp_f,  name='backbone/C2/block1/conv1/beta')
tmp_f = get_filters(reader, 'resnet_model/batch_normalization/gamma')
_ = tf.Variable(tmp_f,  name='backbone/C2/block1/conv1/gamma')
tmp_f = get_filters(reader, 'resnet_model/batch_normalization/moving_mean')
_ = tf.Variable(tmp_f,  name='backbone/C2/block1/conv1/moving_mean')
tmp_f = get_filters(reader, 'resnet_model/batch_normalization/moving_variance')
_ = tf.Variable(tmp_f,  name='backbone/C2/block1/conv1/moving_variance')
# conv2-3
for i in range(3,5):
    tmp_f = get_filters(reader, 'resnet_model/conv2d_' +  str(i) + '/kernel')
    _ = tf.Variable(tmp_f,  name='backbone/C2/block1/conv' + str(i-1) + '/kernel')
    tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(i-2) + '/beta')
    _ = tf.Variable(tmp_f,  name='backbone/C2/block1/conv' + str(i-1) + '/beta')
    tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(i-2) + '/gamma')
    _ = tf.Variable(tmp_f,  name='backbone/C2/block1/conv' + str(i-1) + '/gamma')
    tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(i-2) + '/moving_mean')
    _ = tf.Variable(tmp_f,  name='backbone/C2/block1/conv' + str(i-1) + '/moving_mean')
    tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(i-2) + '/moving_variance')
    _ = tf.Variable(tmp_f,  name='backbone/C2/block1/conv' + str(i-1) + '/moving_variance')
# 2n block, conv1-3
for i in range(1,4):
    tmp_f = get_filters(reader, 'resnet_model/conv2d_' +  str(i+4) + '/kernel')
    _ = tf.Variable(tmp_f,  name='backbone/C2/block2/conv' + str(i) + '/kernel')
    tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(i+2) + '/beta')
    _ = tf.Variable(tmp_f,  name='backbone/C2/block2/conv' + str(i) + '/beta')
    tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(i+2) + '/gamma')
    _ = tf.Variable(tmp_f,  name='backbone/C2/block2/conv' + str(i) + '/gamma')
    tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(i+2) + '/moving_mean')
    _ = tf.Variable(tmp_f,  name='backbone/C2/block2/conv' + str(i) + '/moving_mean')
    tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(i+2) + '/moving_variance')
    _ = tf.Variable(tmp_f,  name='backbone/C2/block2/conv' + str(i) + '/moving_variance')
# 3n block, conv1-3
for i in range(1,4):
    tmp_f = get_filters(reader, 'resnet_model/conv2d_' +  str(i+7) + '/kernel')
    _ = tf.Variable(tmp_f,  name='backbone/C2/block3/conv' + str(i) + '/kernel')
    tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(i+5) + '/beta')
    _ = tf.Variable(tmp_f,  name='backbone/C2/block3/conv' + str(i) + '/beta')
    tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(i+5) + '/gamma')
    _ = tf.Variable(tmp_f,  name='backbone/C2/block3/conv' + str(i) + '/gamma')
    tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(i+5) + '/moving_mean')
    _ = tf.Variable(tmp_f,  name='backbone/C2/block3/conv' + str(i) + '/moving_mean')
    tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(i+5) + '/moving_variance')
    _ = tf.Variable(tmp_f,  name='backbone/C2/block3/conv' + str(i) + '/moving_variance')

################## C3 ###########################
# 1st block, shortcut conv
tmp_f = get_filters(reader, 'resnet_model/conv2d_11/kernel')
tmp_f = trans_filters(tmp_f)
_ = tf.Variable(tmp_f,  name='backbone/C3/block1/shortcut/kernel')
# block 1-4
resconv_i = 12
resbn_i = 9
for block_i in range(1, 5):
    # conv1-3
    for conv_i in range(1,4):
        tmp_f = get_filters(reader, 'resnet_model/conv2d_' +  str(resconv_i) + '/kernel')
        _ = tf.Variable(tmp_f,  name='backbone/C3/block' + str(block_i) + '/conv' + str(conv_i) + '/kernel')
        tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(resbn_i) + '/beta')
        _ = tf.Variable(tmp_f,  name='backbone/C3/block' + str(block_i) + '/conv' + str(conv_i) + '/beta')
        tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(resbn_i) + '/gamma')
        _ = tf.Variable(tmp_f,  name='backbone/C3/block' + str(block_i) + '/conv' + str(conv_i) + '/gamma')
        tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(resbn_i) + '/moving_mean')
        _ = tf.Variable(tmp_f,  name='backbone/C3/block' + str(block_i) + '/conv' + str(conv_i) + '/moving_mean')
        tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(resbn_i) + '/moving_variance')
        _ = tf.Variable(tmp_f,  name='backbone/C3/block' + str(block_i) + '/conv' + str(conv_i) + '/moving_variance')
        resconv_i += 1
        resbn_i += 1

################## C4 ###########################
# 1st block, shortcut conv
tmp_f = get_filters(reader, 'resnet_model/conv2d_24/kernel')
_ = tf.Variable(tmp_f,  name='backbone/C4/block1/shortcut/kernel')
# block 1-6
resconv_i = 25
resbn_i = 21
for block_i in range(1, 7):
    # conv1-3
    for conv_i in range(1,4):
        tmp_f = get_filters(reader, 'resnet_model/conv2d_' +  str(resconv_i) + '/kernel')
        _ = tf.Variable(tmp_f,  name='backbone/C4/block' + str(block_i) + '/conv' + str(conv_i) + '/kernel')
        tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(resbn_i) + '/beta')
        _ = tf.Variable(tmp_f,  name='backbone/C4/block' + str(block_i) + '/conv' + str(conv_i) + '/beta')
        tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(resbn_i) + '/gamma')
        _ = tf.Variable(tmp_f,  name='backbone/C4/block' + str(block_i) + '/conv' + str(conv_i) + '/gamma')
        tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(resbn_i) + '/moving_mean')
        _ = tf.Variable(tmp_f,  name='backbone/C4/block' + str(block_i) + '/conv' + str(conv_i) + '/moving_mean')
        tmp_f = get_filters(reader, 'resnet_model/batch_normalization_' + str(resbn_i) + '/moving_variance')
        _ = tf.Variable(tmp_f,  name='backbone/C4/block' + str(block_i) + '/conv' + str(conv_i) + '/moving_variance')
        resconv_i += 1
        resbn_i += 1
        
print('Renamed kernels created.')
# save to .ckpt file
init_op = tf.global_variables_initializer()
saver = tf.train.Saver()
with tf.Session() as sess:
    sess.run(init_op)
    saver.save(sess=sess, save_path=save_path, write_meta_graph=False)
    
print('Saved ckpt to {}'.format(save_path))
# Out:
# Read filter resnet_model/conv2d/kernel, (7, 7, 3, 64)
# Read filter resnet_model/conv2d_1/kernel, (1, 1, 64, 256)
# Read filter resnet_model/conv2d_2/kernel, (1, 1, 64, 64)
# Read filter resnet_model/batch_normalization/beta, (64,)
# Read filter resnet_model/batch_normalization/gamma, (64,)
# Read filter resnet_model/batch_normalization/moving_mean, (64,)
# Read filter resnet_model/batch_normalization/moving_variance, (64,)
# Read filter resnet_model/conv2d_3/kernel, (3, 3, 64, 64)
# Read filter resnet_model/batch_normalization_1/beta, (64,)
# Read filter resnet_model/batch_normalization_1/gamma, (64,)
# Read filter resnet_model/batch_normalization_1/moving_mean, (64,)
# Read filter resnet_model/batch_normalization_1/moving_variance, (64,)
# Read filter resnet_model/conv2d_4/kernel, (1, 1, 64, 256)
# Read filter resnet_model/batch_normalization_2/beta, (64,)
# Read filter resnet_model/batch_normalization_2/gamma, (64,)
# Read filter resnet_model/batch_normalization_2/moving_mean, (64,)
# Read filter resnet_model/batch_normalization_2/moving_variance, (64,)
# Read filter resnet_model/conv2d_5/kernel, (1, 1, 256, 64)
# Read filter resnet_model/batch_normalization_3/beta, (256,)
# Read filter resnet_model/batch_normalization_3/gamma, (256,)
# Read filter resnet_model/batch_normalization_3/moving_mean, (256,)
# Read filter resnet_model/batch_normalization_3/moving_variance, (256,)
# Read filter resnet_model/conv2d_6/kernel, (3, 3, 64, 64)
# Read filter resnet_model/batch_normalization_4/beta, (64,)
# Read filter resnet_model/batch_normalization_4/gamma, (64,)
# Read filter resnet_model/batch_normalization_4/moving_mean, (64,)
# Read filter resnet_model/batch_normalization_4/moving_variance, (64,)
# Read filter resnet_model/conv2d_7/kernel, (1, 1, 64, 256)
# Read filter resnet_model/batch_normalization_5/beta, (64,)
# Read filter resnet_model/batch_normalization_5/gamma, (64,)
# Read filter resnet_model/batch_normalization_5/moving_mean, (64,)
# Read filter resnet_model/batch_normalization_5/moving_variance, (64,)
# Read filter resnet_model/conv2d_8/kernel, (1, 1, 256, 64)
# Read filter resnet_model/batch_normalization_6/beta, (256,)
# Read filter resnet_model/batch_normalization_6/gamma, (256,)
# Read filter resnet_model/batch_normalization_6/moving_mean, (256,)
# Read filter resnet_model/batch_normalization_6/moving_variance, (256,)
# Read filter resnet_model/conv2d_9/kernel, (3, 3, 64, 64)
# Read filter resnet_model/batch_normalization_7/beta, (64,)
# Read filter resnet_model/batch_normalization_7/gamma, (64,)
# Read filter resnet_model/batch_normalization_7/moving_mean, (64,)
# Read filter resnet_model/batch_normalization_7/moving_variance, (64,)
# Read filter resnet_model/conv2d_10/kernel, (1, 1, 64, 256)
# Read filter resnet_model/batch_normalization_8/beta, (64,)
# Read filter resnet_model/batch_normalization_8/gamma, (64,)
# Read filter resnet_model/batch_normalization_8/moving_mean, (64,)
# Read filter resnet_model/batch_normalization_8/moving_variance, (64,)
# Read filter resnet_model/conv2d_11/kernel, (1, 1, 256, 512)
# Read filter resnet_model/conv2d_12/kernel, (1, 1, 256, 128)
# Read filter resnet_model/batch_normalization_9/beta, (256,)
# Read filter resnet_model/batch_normalization_9/gamma, (256,)
# Read filter resnet_model/batch_normalization_9/moving_mean, (256,)
# Read filter resnet_model/batch_normalization_9/moving_variance, (256,)
# Read filter resnet_model/conv2d_13/kernel, (3, 3, 128, 128)
# Read filter resnet_model/batch_normalization_10/beta, (128,)
# Read filter resnet_model/batch_normalization_10/gamma, (128,)
# Read filter resnet_model/batch_normalization_10/moving_mean, (128,)
# Read filter resnet_model/batch_normalization_10/moving_variance, (128,)
# Read filter resnet_model/conv2d_14/kernel, (1, 1, 128, 512)
# Read filter resnet_model/batch_normalization_11/beta, (128,)
# Read filter resnet_model/batch_normalization_11/gamma, (128,)
# Read filter resnet_model/batch_normalization_11/moving_mean, (128,)
# Read filter resnet_model/batch_normalization_11/moving_variance, (128,)
# Read filter resnet_model/conv2d_15/kernel, (1, 1, 512, 128)
# Read filter resnet_model/batch_normalization_12/beta, (512,)
# Read filter resnet_model/batch_normalization_12/gamma, (512,)
# Read filter resnet_model/batch_normalization_12/moving_mean, (512,)
# Read filter resnet_model/batch_normalization_12/moving_variance, (512,)
# Read filter resnet_model/conv2d_16/kernel, (3, 3, 128, 128)
# Read filter resnet_model/batch_normalization_13/beta, (128,)
# Read filter resnet_model/batch_normalization_13/gamma, (128,)
# Read filter resnet_model/batch_normalization_13/moving_mean, (128,)
# Read filter resnet_model/batch_normalization_13/moving_variance, (128,)
# Read filter resnet_model/conv2d_17/kernel, (1, 1, 128, 512)
# Read filter resnet_model/batch_normalization_14/beta, (128,)
# Read filter resnet_model/batch_normalization_14/gamma, (128,)
# Read filter resnet_model/batch_normalization_14/moving_mean, (128,)
# Read filter resnet_model/batch_normalization_14/moving_variance, (128,)
# Read filter resnet_model/conv2d_18/kernel, (1, 1, 512, 128)
# Read filter resnet_model/batch_normalization_15/beta, (512,)
# Read filter resnet_model/batch_normalization_15/gamma, (512,)
# Read filter resnet_model/batch_normalization_15/moving_mean, (512,)
# Read filter resnet_model/batch_normalization_15/moving_variance, (512,)
# Read filter resnet_model/conv2d_19/kernel, (3, 3, 128, 128)
# Read filter resnet_model/batch_normalization_16/beta, (128,)
# Read filter resnet_model/batch_normalization_16/gamma, (128,)
# Read filter resnet_model/batch_normalization_16/moving_mean, (128,)
# Read filter resnet_model/batch_normalization_16/moving_variance, (128,)
# Read filter resnet_model/conv2d_20/kernel, (1, 1, 128, 512)
# Read filter resnet_model/batch_normalization_17/beta, (128,)
# Read filter resnet_model/batch_normalization_17/gamma, (128,)
# Read filter resnet_model/batch_normalization_17/moving_mean, (128,)
# Read filter resnet_model/batch_normalization_17/moving_variance, (128,)
# Read filter resnet_model/conv2d_21/kernel, (1, 1, 512, 128)
# Read filter resnet_model/batch_normalization_18/beta, (512,)
# Read filter resnet_model/batch_normalization_18/gamma, (512,)
# Read filter resnet_model/batch_normalization_18/moving_mean, (512,)
# Read filter resnet_model/batch_normalization_18/moving_variance, (512,)
# Read filter resnet_model/conv2d_22/kernel, (3, 3, 128, 128)
# Read filter resnet_model/batch_normalization_19/beta, (128,)
# Read filter resnet_model/batch_normalization_19/gamma, (128,)
# Read filter resnet_model/batch_normalization_19/moving_mean, (128,)
# Read filter resnet_model/batch_normalization_19/moving_variance, (128,)
# Read filter resnet_model/conv2d_23/kernel, (1, 1, 128, 512)
# Read filter resnet_model/batch_normalization_20/beta, (128,)
# Read filter resnet_model/batch_normalization_20/gamma, (128,)
# Read filter resnet_model/batch_normalization_20/moving_mean, (128,)
# Read filter resnet_model/batch_normalization_20/moving_variance, (128,)
# Read filter resnet_model/conv2d_24/kernel, (1, 1, 512, 1024)
# Read filter resnet_model/conv2d_25/kernel, (1, 1, 512, 256)
# Read filter resnet_model/batch_normalization_21/beta, (512,)
# Read filter resnet_model/batch_normalization_21/gamma, (512,)
# Read filter resnet_model/batch_normalization_21/moving_mean, (512,)
# Read filter resnet_model/batch_normalization_21/moving_variance, (512,)
# Read filter resnet_model/conv2d_26/kernel, (3, 3, 256, 256)
# Read filter resnet_model/batch_normalization_22/beta, (256,)
# Read filter resnet_model/batch_normalization_22/gamma, (256,)
# Read filter resnet_model/batch_normalization_22/moving_mean, (256,)
# Read filter resnet_model/batch_normalization_22/moving_variance, (256,)
# Read filter resnet_model/conv2d_27/kernel, (1, 1, 256, 1024)
# Read filter resnet_model/batch_normalization_23/beta, (256,)
# Read filter resnet_model/batch_normalization_23/gamma, (256,)
# Read filter resnet_model/batch_normalization_23/moving_mean, (256,)
# Read filter resnet_model/batch_normalization_23/moving_variance, (256,)
# Read filter resnet_model/conv2d_28/kernel, (1, 1, 1024, 256)
# Read filter resnet_model/batch_normalization_24/beta, (1024,)
# Read filter resnet_model/batch_normalization_24/gamma, (1024,)
# Read filter resnet_model/batch_normalization_24/moving_mean, (1024,)
# Read filter resnet_model/batch_normalization_24/moving_variance, (1024,)
# Read filter resnet_model/conv2d_29/kernel, (3, 3, 256, 256)
# Read filter resnet_model/batch_normalization_25/beta, (256,)
# Read filter resnet_model/batch_normalization_25/gamma, (256,)
# Read filter resnet_model/batch_normalization_25/moving_mean, (256,)
# Read filter resnet_model/batch_normalization_25/moving_variance, (256,)
# Read filter resnet_model/conv2d_30/kernel, (1, 1, 256, 1024)
# Read filter resnet_model/batch_normalization_26/beta, (256,)
# Read filter resnet_model/batch_normalization_26/gamma, (256,)
# Read filter resnet_model/batch_normalization_26/moving_mean, (256,)
# Read filter resnet_model/batch_normalization_26/moving_variance, (256,)
# Read filter resnet_model/conv2d_31/kernel, (1, 1, 1024, 256)
# Read filter resnet_model/batch_normalization_27/beta, (1024,)
# Read filter resnet_model/batch_normalization_27/gamma, (1024,)
# Read filter resnet_model/batch_normalization_27/moving_mean, (1024,)
# Read filter resnet_model/batch_normalization_27/moving_variance, (1024,)
# Read filter resnet_model/conv2d_32/kernel, (3, 3, 256, 256)
# Read filter resnet_model/batch_normalization_28/beta, (256,)
# Read filter resnet_model/batch_normalization_28/gamma, (256,)
# Read filter resnet_model/batch_normalization_28/moving_mean, (256,)
# Read filter resnet_model/batch_normalization_28/moving_variance, (256,)
# Read filter resnet_model/conv2d_33/kernel, (1, 1, 256, 1024)
# Read filter resnet_model/batch_normalization_29/beta, (256,)
# Read filter resnet_model/batch_normalization_29/gamma, (256,)
# Read filter resnet_model/batch_normalization_29/moving_mean, (256,)
# Read filter resnet_model/batch_normalization_29/moving_variance, (256,)
# Read filter resnet_model/conv2d_34/kernel, (1, 1, 1024, 256)
# Read filter resnet_model/batch_normalization_30/beta, (1024,)
# Read filter resnet_model/batch_normalization_30/gamma, (1024,)
# Read filter resnet_model/batch_normalization_30/moving_mean, (1024,)
# Read filter resnet_model/batch_normalization_30/moving_variance, (1024,)
# Read filter resnet_model/conv2d_35/kernel, (3, 3, 256, 256)
# Read filter resnet_model/batch_normalization_31/beta, (256,)
# Read filter resnet_model/batch_normalization_31/gamma, (256,)
# Read filter resnet_model/batch_normalization_31/moving_mean, (256,)
# Read filter resnet_model/batch_normalization_31/moving_variance, (256,)
# Read filter resnet_model/conv2d_36/kernel, (1, 1, 256, 1024)
# Read filter resnet_model/batch_normalization_32/beta, (256,)
# Read filter resnet_model/batch_normalization_32/gamma, (256,)
# Read filter resnet_model/batch_normalization_32/moving_mean, (256,)
# Read filter resnet_model/batch_normalization_32/moving_variance, (256,)
# Read filter resnet_model/conv2d_37/kernel, (1, 1, 1024, 256)
# Read filter resnet_model/batch_normalization_33/beta, (1024,)
# Read filter resnet_model/batch_normalization_33/gamma, (1024,)
# Read filter resnet_model/batch_normalization_33/moving_mean, (1024,)
# Read filter resnet_model/batch_normalization_33/moving_variance, (1024,)
# Read filter resnet_model/conv2d_38/kernel, (3, 3, 256, 256)
# Read filter resnet_model/batch_normalization_34/beta, (256,)
# Read filter resnet_model/batch_normalization_34/gamma, (256,)
# Read filter resnet_model/batch_normalization_34/moving_mean, (256,)
# Read filter resnet_model/batch_normalization_34/moving_variance, (256,)
# Read filter resnet_model/conv2d_39/kernel, (1, 1, 256, 1024)
# Read filter resnet_model/batch_normalization_35/beta, (256,)
# Read filter resnet_model/batch_normalization_35/gamma, (256,)
# Read filter resnet_model/batch_normalization_35/moving_mean, (256,)
# Read filter resnet_model/batch_normalization_35/moving_variance, (256,)
# Read filter resnet_model/conv2d_40/kernel, (1, 1, 1024, 256)
# Read filter resnet_model/batch_normalization_36/beta, (1024,)
# Read filter resnet_model/batch_normalization_36/gamma, (1024,)
# Read filter resnet_model/batch_normalization_36/moving_mean, (1024,)
# Read filter resnet_model/batch_normalization_36/moving_variance, (1024,)
# Read filter resnet_model/conv2d_41/kernel, (3, 3, 256, 256)
# Read filter resnet_model/batch_normalization_37/beta, (256,)
# Read filter resnet_model/batch_normalization_37/gamma, (256,)
# Read filter resnet_model/batch_normalization_37/moving_mean, (256,)
# Read filter resnet_model/batch_normalization_37/moving_variance, (256,)
# Read filter resnet_model/conv2d_42/kernel, (1, 1, 256, 1024)
# Read filter resnet_model/batch_normalization_38/beta, (256,)
# Read filter resnet_model/batch_normalization_38/gamma, (256,)
# Read filter resnet_model/batch_normalization_38/moving_mean, (256,)
# Read filter resnet_model/batch_normalization_38/moving_variance, (256,)
# Renamed kernels created.
# Saved ckpt to /work/wangyu/imagenet/resnet_v2_imagenet_transformed_mask/resnet50_v2_mask.ckpt
