# %%
from tensorflow.python.tools import inspect_checkpoint as chkp
chkp.print_tensors_in_checkpoint_file("../data/resnet_v2_imagenet_checkpoint/model.ckpt-258931", tensor_name='', all_tensors=False)
# Out:
# global_step (DT_INT64) []
# resnet_model/batch_normalization/beta (DT_FLOAT) [64]
# resnet_model/batch_normalization/beta/Momentum (DT_FLOAT) [64]
# resnet_model/batch_normalization/gamma (DT_FLOAT) [64]
# resnet_model/batch_normalization/gamma/Momentum (DT_FLOAT) [64]
# resnet_model/batch_normalization/moving_mean (DT_FLOAT) [64]
# resnet_model/batch_normalization/moving_variance (DT_FLOAT) [64]
# resnet_model/batch_normalization_1/beta (DT_FLOAT) [64]
# resnet_model/batch_normalization_1/beta/Momentum (DT_FLOAT) [64]
# resnet_model/batch_normalization_1/gamma (DT_FLOAT) [64]
# resnet_model/batch_normalization_1/gamma/Momentum (DT_FLOAT) [64]
# resnet_model/batch_normalization_1/moving_mean (DT_FLOAT) [64]
# resnet_model/batch_normalization_1/moving_variance (DT_FLOAT) [64]
# resnet_model/batch_normalization_10/beta (DT_FLOAT) [128]
# resnet_model/batch_normalization_10/beta/Momentum (DT_FLOAT) [128]
# resnet_model/batch_normalization_10/gamma (DT_FLOAT) [128]
# resnet_model/batch_normalization_10/gamma/Momentum (DT_FLOAT) [128]
# resnet_model/batch_normalization_10/moving_mean (DT_FLOAT) [128]
# resnet_model/batch_normalization_10/moving_variance (DT_FLOAT) [128]
# resnet_model/batch_normalization_11/beta (DT_FLOAT) [128]
# resnet_model/batch_normalization_11/beta/Momentum (DT_FLOAT) [128]
# resnet_model/batch_normalization_11/gamma (DT_FLOAT) [128]
# resnet_model/batch_normalization_11/gamma/Momentum (DT_FLOAT) [128]
# resnet_model/batch_normalization_11/moving_mean (DT_FLOAT) [128]
# resnet_model/batch_normalization_11/moving_variance (DT_FLOAT) [128]
# resnet_model/batch_normalization_12/beta (DT_FLOAT) [512]
# resnet_model/batch_normalization_12/beta/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_12/gamma (DT_FLOAT) [512]
# resnet_model/batch_normalization_12/gamma/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_12/moving_mean (DT_FLOAT) [512]
# resnet_model/batch_normalization_12/moving_variance (DT_FLOAT) [512]
# resnet_model/batch_normalization_13/beta (DT_FLOAT) [128]
# resnet_model/batch_normalization_13/beta/Momentum (DT_FLOAT) [128]
# resnet_model/batch_normalization_13/gamma (DT_FLOAT) [128]
# resnet_model/batch_normalization_13/gamma/Momentum (DT_FLOAT) [128]
# resnet_model/batch_normalization_13/moving_mean (DT_FLOAT) [128]
# resnet_model/batch_normalization_13/moving_variance (DT_FLOAT) [128]
# resnet_model/batch_normalization_14/beta (DT_FLOAT) [128]
# resnet_model/batch_normalization_14/beta/Momentum (DT_FLOAT) [128]
# resnet_model/batch_normalization_14/gamma (DT_FLOAT) [128]
# resnet_model/batch_normalization_14/gamma/Momentum (DT_FLOAT) [128]
# resnet_model/batch_normalization_14/moving_mean (DT_FLOAT) [128]
# resnet_model/batch_normalization_14/moving_variance (DT_FLOAT) [128]
# resnet_model/batch_normalization_15/beta (DT_FLOAT) [512]
# resnet_model/batch_normalization_15/beta/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_15/gamma (DT_FLOAT) [512]
# resnet_model/batch_normalization_15/gamma/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_15/moving_mean (DT_FLOAT) [512]
# resnet_model/batch_normalization_15/moving_variance (DT_FLOAT) [512]
# resnet_model/batch_normalization_16/beta (DT_FLOAT) [128]
# resnet_model/batch_normalization_16/beta/Momentum (DT_FLOAT) [128]
# resnet_model/batch_normalization_16/gamma (DT_FLOAT) [128]
# resnet_model/batch_normalization_16/gamma/Momentum (DT_FLOAT) [128]
# resnet_model/batch_normalization_16/moving_mean (DT_FLOAT) [128]
# resnet_model/batch_normalization_16/moving_variance (DT_FLOAT) [128]
# resnet_model/batch_normalization_17/beta (DT_FLOAT) [128]
# resnet_model/batch_normalization_17/beta/Momentum (DT_FLOAT) [128]
# resnet_model/batch_normalization_17/gamma (DT_FLOAT) [128]
# resnet_model/batch_normalization_17/gamma/Momentum (DT_FLOAT) [128]
# resnet_model/batch_normalization_17/moving_mean (DT_FLOAT) [128]
# resnet_model/batch_normalization_17/moving_variance (DT_FLOAT) [128]
# resnet_model/batch_normalization_18/beta (DT_FLOAT) [512]
# resnet_model/batch_normalization_18/beta/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_18/gamma (DT_FLOAT) [512]
# resnet_model/batch_normalization_18/gamma/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_18/moving_mean (DT_FLOAT) [512]
# resnet_model/batch_normalization_18/moving_variance (DT_FLOAT) [512]
# resnet_model/batch_normalization_19/beta (DT_FLOAT) [128]
# resnet_model/batch_normalization_19/beta/Momentum (DT_FLOAT) [128]
# resnet_model/batch_normalization_19/gamma (DT_FLOAT) [128]
# resnet_model/batch_normalization_19/gamma/Momentum (DT_FLOAT) [128]
# resnet_model/batch_normalization_19/moving_mean (DT_FLOAT) [128]
# resnet_model/batch_normalization_19/moving_variance (DT_FLOAT) [128]
# resnet_model/batch_normalization_2/beta (DT_FLOAT) [64]
# resnet_model/batch_normalization_2/beta/Momentum (DT_FLOAT) [64]
# resnet_model/batch_normalization_2/gamma (DT_FLOAT) [64]
# resnet_model/batch_normalization_2/gamma/Momentum (DT_FLOAT) [64]
# resnet_model/batch_normalization_2/moving_mean (DT_FLOAT) [64]
# resnet_model/batch_normalization_2/moving_variance (DT_FLOAT) [64]
# resnet_model/batch_normalization_20/beta (DT_FLOAT) [128]
# resnet_model/batch_normalization_20/beta/Momentum (DT_FLOAT) [128]
# resnet_model/batch_normalization_20/gamma (DT_FLOAT) [128]
# resnet_model/batch_normalization_20/gamma/Momentum (DT_FLOAT) [128]
# resnet_model/batch_normalization_20/moving_mean (DT_FLOAT) [128]
# resnet_model/batch_normalization_20/moving_variance (DT_FLOAT) [128]
# resnet_model/batch_normalization_21/beta (DT_FLOAT) [512]
# resnet_model/batch_normalization_21/beta/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_21/gamma (DT_FLOAT) [512]
# resnet_model/batch_normalization_21/gamma/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_21/moving_mean (DT_FLOAT) [512]
# resnet_model/batch_normalization_21/moving_variance (DT_FLOAT) [512]
# resnet_model/batch_normalization_22/beta (DT_FLOAT) [256]
# resnet_model/batch_normalization_22/beta/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_22/gamma (DT_FLOAT) [256]
# resnet_model/batch_normalization_22/gamma/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_22/moving_mean (DT_FLOAT) [256]
# resnet_model/batch_normalization_22/moving_variance (DT_FLOAT) [256]
# resnet_model/batch_normalization_23/beta (DT_FLOAT) [256]
# resnet_model/batch_normalization_23/beta/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_23/gamma (DT_FLOAT) [256]
# resnet_model/batch_normalization_23/gamma/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_23/moving_mean (DT_FLOAT) [256]
# resnet_model/batch_normalization_23/moving_variance (DT_FLOAT) [256]
# resnet_model/batch_normalization_24/beta (DT_FLOAT) [1024]
# resnet_model/batch_normalization_24/beta/Momentum (DT_FLOAT) [1024]
# resnet_model/batch_normalization_24/gamma (DT_FLOAT) [1024]
# resnet_model/batch_normalization_24/gamma/Momentum (DT_FLOAT) [1024]
# resnet_model/batch_normalization_24/moving_mean (DT_FLOAT) [1024]
# resnet_model/batch_normalization_24/moving_variance (DT_FLOAT) [1024]
# resnet_model/batch_normalization_25/beta (DT_FLOAT) [256]
# resnet_model/batch_normalization_25/beta/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_25/gamma (DT_FLOAT) [256]
# resnet_model/batch_normalization_25/gamma/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_25/moving_mean (DT_FLOAT) [256]
# resnet_model/batch_normalization_25/moving_variance (DT_FLOAT) [256]
# resnet_model/batch_normalization_26/beta (DT_FLOAT) [256]
# resnet_model/batch_normalization_26/beta/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_26/gamma (DT_FLOAT) [256]
# resnet_model/batch_normalization_26/gamma/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_26/moving_mean (DT_FLOAT) [256]
# resnet_model/batch_normalization_26/moving_variance (DT_FLOAT) [256]
# resnet_model/batch_normalization_27/beta (DT_FLOAT) [1024]
# resnet_model/batch_normalization_27/beta/Momentum (DT_FLOAT) [1024]
# resnet_model/batch_normalization_27/gamma (DT_FLOAT) [1024]
# resnet_model/batch_normalization_27/gamma/Momentum (DT_FLOAT) [1024]
# resnet_model/batch_normalization_27/moving_mean (DT_FLOAT) [1024]
# resnet_model/batch_normalization_27/moving_variance (DT_FLOAT) [1024]
# resnet_model/batch_normalization_28/beta (DT_FLOAT) [256]
# resnet_model/batch_normalization_28/beta/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_28/gamma (DT_FLOAT) [256]
# resnet_model/batch_normalization_28/gamma/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_28/moving_mean (DT_FLOAT) [256]
# resnet_model/batch_normalization_28/moving_variance (DT_FLOAT) [256]
# resnet_model/batch_normalization_29/beta (DT_FLOAT) [256]
# resnet_model/batch_normalization_29/beta/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_29/gamma (DT_FLOAT) [256]
# resnet_model/batch_normalization_29/gamma/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_29/moving_mean (DT_FLOAT) [256]
# resnet_model/batch_normalization_29/moving_variance (DT_FLOAT) [256]
# resnet_model/batch_normalization_3/beta (DT_FLOAT) [256]
# resnet_model/batch_normalization_3/beta/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_3/gamma (DT_FLOAT) [256]
# resnet_model/batch_normalization_3/gamma/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_3/moving_mean (DT_FLOAT) [256]
# resnet_model/batch_normalization_3/moving_variance (DT_FLOAT) [256]
# resnet_model/batch_normalization_30/beta (DT_FLOAT) [1024]
# resnet_model/batch_normalization_30/beta/Momentum (DT_FLOAT) [1024]
# resnet_model/batch_normalization_30/gamma (DT_FLOAT) [1024]
# resnet_model/batch_normalization_30/gamma/Momentum (DT_FLOAT) [1024]
# resnet_model/batch_normalization_30/moving_mean (DT_FLOAT) [1024]
# resnet_model/batch_normalization_30/moving_variance (DT_FLOAT) [1024]
# resnet_model/batch_normalization_31/beta (DT_FLOAT) [256]
# resnet_model/batch_normalization_31/beta/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_31/gamma (DT_FLOAT) [256]
# resnet_model/batch_normalization_31/gamma/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_31/moving_mean (DT_FLOAT) [256]
# resnet_model/batch_normalization_31/moving_variance (DT_FLOAT) [256]
# resnet_model/batch_normalization_32/beta (DT_FLOAT) [256]
# resnet_model/batch_normalization_32/beta/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_32/gamma (DT_FLOAT) [256]
# resnet_model/batch_normalization_32/gamma/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_32/moving_mean (DT_FLOAT) [256]
# resnet_model/batch_normalization_32/moving_variance (DT_FLOAT) [256]
# resnet_model/batch_normalization_33/beta (DT_FLOAT) [1024]
# resnet_model/batch_normalization_33/beta/Momentum (DT_FLOAT) [1024]
# resnet_model/batch_normalization_33/gamma (DT_FLOAT) [1024]
# resnet_model/batch_normalization_33/gamma/Momentum (DT_FLOAT) [1024]
# resnet_model/batch_normalization_33/moving_mean (DT_FLOAT) [1024]
# resnet_model/batch_normalization_33/moving_variance (DT_FLOAT) [1024]
# resnet_model/batch_normalization_34/beta (DT_FLOAT) [256]
# resnet_model/batch_normalization_34/beta/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_34/gamma (DT_FLOAT) [256]
# resnet_model/batch_normalization_34/gamma/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_34/moving_mean (DT_FLOAT) [256]
# resnet_model/batch_normalization_34/moving_variance (DT_FLOAT) [256]
# resnet_model/batch_normalization_35/beta (DT_FLOAT) [256]
# resnet_model/batch_normalization_35/beta/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_35/gamma (DT_FLOAT) [256]
# resnet_model/batch_normalization_35/gamma/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_35/moving_mean (DT_FLOAT) [256]
# resnet_model/batch_normalization_35/moving_variance (DT_FLOAT) [256]
# resnet_model/batch_normalization_36/beta (DT_FLOAT) [1024]
# resnet_model/batch_normalization_36/beta/Momentum (DT_FLOAT) [1024]
# resnet_model/batch_normalization_36/gamma (DT_FLOAT) [1024]
# resnet_model/batch_normalization_36/gamma/Momentum (DT_FLOAT) [1024]
# resnet_model/batch_normalization_36/moving_mean (DT_FLOAT) [1024]
# resnet_model/batch_normalization_36/moving_variance (DT_FLOAT) [1024]
# resnet_model/batch_normalization_37/beta (DT_FLOAT) [256]
# resnet_model/batch_normalization_37/beta/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_37/gamma (DT_FLOAT) [256]
# resnet_model/batch_normalization_37/gamma/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_37/moving_mean (DT_FLOAT) [256]
# resnet_model/batch_normalization_37/moving_variance (DT_FLOAT) [256]
# resnet_model/batch_normalization_38/beta (DT_FLOAT) [256]
# resnet_model/batch_normalization_38/beta/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_38/gamma (DT_FLOAT) [256]
# resnet_model/batch_normalization_38/gamma/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_38/moving_mean (DT_FLOAT) [256]
# resnet_model/batch_normalization_38/moving_variance (DT_FLOAT) [256]
# resnet_model/batch_normalization_39/beta (DT_FLOAT) [1024]
# resnet_model/batch_normalization_39/beta/Momentum (DT_FLOAT) [1024]
# resnet_model/batch_normalization_39/gamma (DT_FLOAT) [1024]
# resnet_model/batch_normalization_39/gamma/Momentum (DT_FLOAT) [1024]
# resnet_model/batch_normalization_39/moving_mean (DT_FLOAT) [1024]
# resnet_model/batch_normalization_39/moving_variance (DT_FLOAT) [1024]
# resnet_model/batch_normalization_4/beta (DT_FLOAT) [64]
# resnet_model/batch_normalization_4/beta/Momentum (DT_FLOAT) [64]
# resnet_model/batch_normalization_4/gamma (DT_FLOAT) [64]
# resnet_model/batch_normalization_4/gamma/Momentum (DT_FLOAT) [64]
# resnet_model/batch_normalization_4/moving_mean (DT_FLOAT) [64]
# resnet_model/batch_normalization_4/moving_variance (DT_FLOAT) [64]
# resnet_model/batch_normalization_40/beta (DT_FLOAT) [512]
# resnet_model/batch_normalization_40/beta/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_40/gamma (DT_FLOAT) [512]
# resnet_model/batch_normalization_40/gamma/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_40/moving_mean (DT_FLOAT) [512]
# resnet_model/batch_normalization_40/moving_variance (DT_FLOAT) [512]
# resnet_model/batch_normalization_41/beta (DT_FLOAT) [512]
# resnet_model/batch_normalization_41/beta/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_41/gamma (DT_FLOAT) [512]
# resnet_model/batch_normalization_41/gamma/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_41/moving_mean (DT_FLOAT) [512]
# resnet_model/batch_normalization_41/moving_variance (DT_FLOAT) [512]
# resnet_model/batch_normalization_42/beta (DT_FLOAT) [2048]
# resnet_model/batch_normalization_42/beta/Momentum (DT_FLOAT) [2048]
# resnet_model/batch_normalization_42/gamma (DT_FLOAT) [2048]
# resnet_model/batch_normalization_42/gamma/Momentum (DT_FLOAT) [2048]
# resnet_model/batch_normalization_42/moving_mean (DT_FLOAT) [2048]
# resnet_model/batch_normalization_42/moving_variance (DT_FLOAT) [2048]
# resnet_model/batch_normalization_43/beta (DT_FLOAT) [512]
# resnet_model/batch_normalization_43/beta/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_43/gamma (DT_FLOAT) [512]
# resnet_model/batch_normalization_43/gamma/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_43/moving_mean (DT_FLOAT) [512]
# resnet_model/batch_normalization_43/moving_variance (DT_FLOAT) [512]
# resnet_model/batch_normalization_44/beta (DT_FLOAT) [512]
# resnet_model/batch_normalization_44/beta/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_44/gamma (DT_FLOAT) [512]
# resnet_model/batch_normalization_44/gamma/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_44/moving_mean (DT_FLOAT) [512]
# resnet_model/batch_normalization_44/moving_variance (DT_FLOAT) [512]
# resnet_model/batch_normalization_45/beta (DT_FLOAT) [2048]
# resnet_model/batch_normalization_45/beta/Momentum (DT_FLOAT) [2048]
# resnet_model/batch_normalization_45/gamma (DT_FLOAT) [2048]
# resnet_model/batch_normalization_45/gamma/Momentum (DT_FLOAT) [2048]
# resnet_model/batch_normalization_45/moving_mean (DT_FLOAT) [2048]
# resnet_model/batch_normalization_45/moving_variance (DT_FLOAT) [2048]
# resnet_model/batch_normalization_46/beta (DT_FLOAT) [512]
# resnet_model/batch_normalization_46/beta/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_46/gamma (DT_FLOAT) [512]
# resnet_model/batch_normalization_46/gamma/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_46/moving_mean (DT_FLOAT) [512]
# resnet_model/batch_normalization_46/moving_variance (DT_FLOAT) [512]
# resnet_model/batch_normalization_47/beta (DT_FLOAT) [512]
# resnet_model/batch_normalization_47/beta/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_47/gamma (DT_FLOAT) [512]
# resnet_model/batch_normalization_47/gamma/Momentum (DT_FLOAT) [512]
# resnet_model/batch_normalization_47/moving_mean (DT_FLOAT) [512]
# resnet_model/batch_normalization_47/moving_variance (DT_FLOAT) [512]
# resnet_model/batch_normalization_48/beta (DT_FLOAT) [2048]
# resnet_model/batch_normalization_48/beta/Momentum (DT_FLOAT) [2048]
# resnet_model/batch_normalization_48/gamma (DT_FLOAT) [2048]
# resnet_model/batch_normalization_48/gamma/Momentum (DT_FLOAT) [2048]
# resnet_model/batch_normalization_48/moving_mean (DT_FLOAT) [2048]
# resnet_model/batch_normalization_48/moving_variance (DT_FLOAT) [2048]
# resnet_model/batch_normalization_5/beta (DT_FLOAT) [64]
# resnet_model/batch_normalization_5/beta/Momentum (DT_FLOAT) [64]
# resnet_model/batch_normalization_5/gamma (DT_FLOAT) [64]
# resnet_model/batch_normalization_5/gamma/Momentum (DT_FLOAT) [64]
# resnet_model/batch_normalization_5/moving_mean (DT_FLOAT) [64]
# resnet_model/batch_normalization_5/moving_variance (DT_FLOAT) [64]
# resnet_model/batch_normalization_6/beta (DT_FLOAT) [256]
# resnet_model/batch_normalization_6/beta/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_6/gamma (DT_FLOAT) [256]
# resnet_model/batch_normalization_6/gamma/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_6/moving_mean (DT_FLOAT) [256]
# resnet_model/batch_normalization_6/moving_variance (DT_FLOAT) [256]
# resnet_model/batch_normalization_7/beta (DT_FLOAT) [64]
# resnet_model/batch_normalization_7/beta/Momentum (DT_FLOAT) [64]
# resnet_model/batch_normalization_7/gamma (DT_FLOAT) [64]
# resnet_model/batch_normalization_7/gamma/Momentum (DT_FLOAT) [64]
# resnet_model/batch_normalization_7/moving_mean (DT_FLOAT) [64]
# resnet_model/batch_normalization_7/moving_variance (DT_FLOAT) [64]
# resnet_model/batch_normalization_8/beta (DT_FLOAT) [64]
# resnet_model/batch_normalization_8/beta/Momentum (DT_FLOAT) [64]
# resnet_model/batch_normalization_8/gamma (DT_FLOAT) [64]
# resnet_model/batch_normalization_8/gamma/Momentum (DT_FLOAT) [64]
# resnet_model/batch_normalization_8/moving_mean (DT_FLOAT) [64]
# resnet_model/batch_normalization_8/moving_variance (DT_FLOAT) [64]
# resnet_model/batch_normalization_9/beta (DT_FLOAT) [256]
# resnet_model/batch_normalization_9/beta/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_9/gamma (DT_FLOAT) [256]
# resnet_model/batch_normalization_9/gamma/Momentum (DT_FLOAT) [256]
# resnet_model/batch_normalization_9/moving_mean (DT_FLOAT) [256]
# resnet_model/batch_normalization_9/moving_variance (DT_FLOAT) [256]
# resnet_model/conv2d/kernel (DT_FLOAT) [7,7,3,64]
# resnet_model/conv2d/kernel/Momentum (DT_FLOAT) [7,7,3,64]
# resnet_model/conv2d_1/kernel (DT_FLOAT) [1,1,64,256]
# resnet_model/conv2d_1/kernel/Momentum (DT_FLOAT) [1,1,64,256]
# resnet_model/conv2d_10/kernel (DT_FLOAT) [1,1,64,256]
# resnet_model/conv2d_10/kernel/Momentum (DT_FLOAT) [1,1,64,256]
# resnet_model/conv2d_11/kernel (DT_FLOAT) [1,1,256,512]
# resnet_model/conv2d_11/kernel/Momentum (DT_FLOAT) [1,1,256,512]
# resnet_model/conv2d_12/kernel (DT_FLOAT) [1,1,256,128]
# resnet_model/conv2d_12/kernel/Momentum (DT_FLOAT) [1,1,256,128]
# resnet_model/conv2d_13/kernel (DT_FLOAT) [3,3,128,128]
# resnet_model/conv2d_13/kernel/Momentum (DT_FLOAT) [3,3,128,128]
# resnet_model/conv2d_14/kernel (DT_FLOAT) [1,1,128,512]
# resnet_model/conv2d_14/kernel/Momentum (DT_FLOAT) [1,1,128,512]
# resnet_model/conv2d_15/kernel (DT_FLOAT) [1,1,512,128]
# resnet_model/conv2d_15/kernel/Momentum (DT_FLOAT) [1,1,512,128]
# resnet_model/conv2d_16/kernel (DT_FLOAT) [3,3,128,128]
# resnet_model/conv2d_16/kernel/Momentum (DT_FLOAT) [3,3,128,128]
# resnet_model/conv2d_17/kernel (DT_FLOAT) [1,1,128,512]
# resnet_model/conv2d_17/kernel/Momentum (DT_FLOAT) [1,1,128,512]
# resnet_model/conv2d_18/kernel (DT_FLOAT) [1,1,512,128]
# resnet_model/conv2d_18/kernel/Momentum (DT_FLOAT) [1,1,512,128]
# resnet_model/conv2d_19/kernel (DT_FLOAT) [3,3,128,128]
# resnet_model/conv2d_19/kernel/Momentum (DT_FLOAT) [3,3,128,128]
# resnet_model/conv2d_2/kernel (DT_FLOAT) [1,1,64,64]
# resnet_model/conv2d_2/kernel/Momentum (DT_FLOAT) [1,1,64,64]
# resnet_model/conv2d_20/kernel (DT_FLOAT) [1,1,128,512]
# resnet_model/conv2d_20/kernel/Momentum (DT_FLOAT) [1,1,128,512]
# resnet_model/conv2d_21/kernel (DT_FLOAT) [1,1,512,128]
# resnet_model/conv2d_21/kernel/Momentum (DT_FLOAT) [1,1,512,128]
# resnet_model/conv2d_22/kernel (DT_FLOAT) [3,3,128,128]
# resnet_model/conv2d_22/kernel/Momentum (DT_FLOAT) [3,3,128,128]
# resnet_model/conv2d_23/kernel (DT_FLOAT) [1,1,128,512]
# resnet_model/conv2d_23/kernel/Momentum (DT_FLOAT) [1,1,128,512]
# resnet_model/conv2d_24/kernel (DT_FLOAT) [1,1,512,1024]
# resnet_model/conv2d_24/kernel/Momentum (DT_FLOAT) [1,1,512,1024]
# resnet_model/conv2d_25/kernel (DT_FLOAT) [1,1,512,256]
# resnet_model/conv2d_25/kernel/Momentum (DT_FLOAT) [1,1,512,256]
# resnet_model/conv2d_26/kernel (DT_FLOAT) [3,3,256,256]
# resnet_model/conv2d_26/kernel/Momentum (DT_FLOAT) [3,3,256,256]
# resnet_model/conv2d_27/kernel (DT_FLOAT) [1,1,256,1024]
# resnet_model/conv2d_27/kernel/Momentum (DT_FLOAT) [1,1,256,1024]
# resnet_model/conv2d_28/kernel (DT_FLOAT) [1,1,1024,256]
# resnet_model/conv2d_28/kernel/Momentum (DT_FLOAT) [1,1,1024,256]
# resnet_model/conv2d_29/kernel (DT_FLOAT) [3,3,256,256]
# resnet_model/conv2d_29/kernel/Momentum (DT_FLOAT) [3,3,256,256]
# resnet_model/conv2d_3/kernel (DT_FLOAT) [3,3,64,64]
# resnet_model/conv2d_3/kernel/Momentum (DT_FLOAT) [3,3,64,64]
# resnet_model/conv2d_30/kernel (DT_FLOAT) [1,1,256,1024]
# resnet_model/conv2d_30/kernel/Momentum (DT_FLOAT) [1,1,256,1024]
# resnet_model/conv2d_31/kernel (DT_FLOAT) [1,1,1024,256]
# resnet_model/conv2d_31/kernel/Momentum (DT_FLOAT) [1,1,1024,256]
# resnet_model/conv2d_32/kernel (DT_FLOAT) [3,3,256,256]
# resnet_model/conv2d_32/kernel/Momentum (DT_FLOAT) [3,3,256,256]
# resnet_model/conv2d_33/kernel (DT_FLOAT) [1,1,256,1024]
# resnet_model/conv2d_33/kernel/Momentum (DT_FLOAT) [1,1,256,1024]
# resnet_model/conv2d_34/kernel (DT_FLOAT) [1,1,1024,256]
# resnet_model/conv2d_34/kernel/Momentum (DT_FLOAT) [1,1,1024,256]
# resnet_model/conv2d_35/kernel (DT_FLOAT) [3,3,256,256]
# resnet_model/conv2d_35/kernel/Momentum (DT_FLOAT) [3,3,256,256]
# resnet_model/conv2d_36/kernel (DT_FLOAT) [1,1,256,1024]
# resnet_model/conv2d_36/kernel/Momentum (DT_FLOAT) [1,1,256,1024]
# resnet_model/conv2d_37/kernel (DT_FLOAT) [1,1,1024,256]
# resnet_model/conv2d_37/kernel/Momentum (DT_FLOAT) [1,1,1024,256]
# resnet_model/conv2d_38/kernel (DT_FLOAT) [3,3,256,256]
# resnet_model/conv2d_38/kernel/Momentum (DT_FLOAT) [3,3,256,256]
# resnet_model/conv2d_39/kernel (DT_FLOAT) [1,1,256,1024]
# resnet_model/conv2d_39/kernel/Momentum (DT_FLOAT) [1,1,256,1024]
# resnet_model/conv2d_4/kernel (DT_FLOAT) [1,1,64,256]
# resnet_model/conv2d_4/kernel/Momentum (DT_FLOAT) [1,1,64,256]
# resnet_model/conv2d_40/kernel (DT_FLOAT) [1,1,1024,256]
# resnet_model/conv2d_40/kernel/Momentum (DT_FLOAT) [1,1,1024,256]
# resnet_model/conv2d_41/kernel (DT_FLOAT) [3,3,256,256]
# resnet_model/conv2d_41/kernel/Momentum (DT_FLOAT) [3,3,256,256]
# resnet_model/conv2d_42/kernel (DT_FLOAT) [1,1,256,1024]
# resnet_model/conv2d_42/kernel/Momentum (DT_FLOAT) [1,1,256,1024]
# resnet_model/conv2d_43/kernel (DT_FLOAT) [1,1,1024,2048]
# resnet_model/conv2d_43/kernel/Momentum (DT_FLOAT) [1,1,1024,2048]
# resnet_model/conv2d_44/kernel (DT_FLOAT) [1,1,1024,512]
# resnet_model/conv2d_44/kernel/Momentum (DT_FLOAT) [1,1,1024,512]
# resnet_model/conv2d_45/kernel (DT_FLOAT) [3,3,512,512]
# resnet_model/conv2d_45/kernel/Momentum (DT_FLOAT) [3,3,512,512]
# resnet_model/conv2d_46/kernel (DT_FLOAT) [1,1,512,2048]
# resnet_model/conv2d_46/kernel/Momentum (DT_FLOAT) [1,1,512,2048]
# resnet_model/conv2d_47/kernel (DT_FLOAT) [1,1,2048,512]
# resnet_model/conv2d_47/kernel/Momentum (DT_FLOAT) [1,1,2048,512]
# resnet_model/conv2d_48/kernel (DT_FLOAT) [3,3,512,512]
# resnet_model/conv2d_48/kernel/Momentum (DT_FLOAT) [3,3,512,512]
# resnet_model/conv2d_49/kernel (DT_FLOAT) [1,1,512,2048]
# resnet_model/conv2d_49/kernel/Momentum (DT_FLOAT) [1,1,512,2048]
# resnet_model/conv2d_5/kernel (DT_FLOAT) [1,1,256,64]
# resnet_model/conv2d_5/kernel/Momentum (DT_FLOAT) [1,1,256,64]
# resnet_model/conv2d_50/kernel (DT_FLOAT) [1,1,2048,512]
# resnet_model/conv2d_50/kernel/Momentum (DT_FLOAT) [1,1,2048,512]
# resnet_model/conv2d_51/kernel (DT_FLOAT) [3,3,512,512]
# resnet_model/conv2d_51/kernel/Momentum (DT_FLOAT) [3,3,512,512]
# resnet_model/conv2d_52/kernel (DT_FLOAT) [1,1,512,2048]
# resnet_model/conv2d_52/kernel/Momentum (DT_FLOAT) [1,1,512,2048]
# resnet_model/conv2d_6/kernel (DT_FLOAT) [3,3,64,64]
# resnet_model/conv2d_6/kernel/Momentum (DT_FLOAT) [3,3,64,64]
# resnet_model/conv2d_7/kernel (DT_FLOAT) [1,1,64,256]
# resnet_model/conv2d_7/kernel/Momentum (DT_FLOAT) [1,1,64,256]
# resnet_model/conv2d_8/kernel (DT_FLOAT) [1,1,256,64]
# resnet_model/conv2d_8/kernel/Momentum (DT_FLOAT) [1,1,256,64]
# resnet_model/conv2d_9/kernel (DT_FLOAT) [3,3,64,64]
# resnet_model/conv2d_9/kernel/Momentum (DT_FLOAT) [3,3,64,64]
# resnet_model/dense/bias (DT_FLOAT) [1001]
# resnet_model/dense/bias/Momentum (DT_FLOAT) [1001]
# resnet_model/dense/kernel (DT_FLOAT) [2048,1001]
# resnet_model/dense/kernel/Momentum (DT_FLOAT) [2048,1001]
